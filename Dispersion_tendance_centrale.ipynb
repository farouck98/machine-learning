# %%
Importation des packages

# %%
# Importation des bibliothèques nécessaires
#!pip install tabulate
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from tabulate import tabulate

# %% [markdown]
# Chargement des données

# %%
# Chargement du dataset Iris
iris = sns.load_dataset('iris')

# Affichage des premières lignes du dataset
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Calcul des tendances centrales univariées

# %%
# Moyenne
mean = iris.mean(numeric_only=True)
print("Moyenne:\n", mean)

# Médiane
median = iris.median(numeric_only=True)
print("\nMédiane:\n", median)

# Mode
mode = iris.mode(numeric_only=True).iloc[0]
print("\nMode:\n", mode)

# Calcul de la variance pour chaque variable
variance = iris.var(numeric_only=True)

print("\nVariance:\n", variance)

# Calcul des quantiles
quantiles = iris.quantile([0.25, 0.5, 0.75])
print("\nquantiles:\n", quantiles)
# Out:
# Moyenne:
#  sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64
#
# Médiane:
#  sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64
#
# Mode:
#  sepal_length    5.0
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64
#
# Variance:
#  sepal_length    0.685694
# sepal_width     0.189979
# petal_length    3.116278
# petal_width     0.581006
# dtype: float64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 19
#      16 print("\nVariance:\n", variance)
#      18 # Calcul des quantiles
# ---> 19 quantiles = iris.quantile([0.25, 0.5, 0.75])
#      20 print("\nquantiles:\n", quantiles)
#
# ...

# %%
# Analyse des tendances centrales et de la dispersion
# Nous utiliserons la fonction describe() pour obtenir un résumé statistique de chaque variable

# Calcul du résumé statistique avec describe()
summary = iris.describe()


# Affichage d'un tableau bien formaté à l'aide de tabulate
print(tabulate(summary, headers='keys', tablefmt='fancy_grid', numalign="center"))
# Out:
# ╒═══════╤════════════════╤═══════════════╤════════════════╤═══════════════╕
# │       │  sepal_length  │  sepal_width  │  petal_length  │  petal_width  │
# ╞═══════╪════════════════╪═══════════════╪════════════════╪═══════════════╡
# │ count │      150       │      150      │      150       │      150      │
# ├───────┼────────────────┼───────────────┼────────────────┼───────────────┤
# │ mean  │    5.84333     │    3.05733    │     3.758      │    1.19933    │
# ├───────┼────────────────┼───────────────┼────────────────┼───────────────┤
# │ std   │    0.828066    │   0.435866    │     1.7653     │   0.762238    │
# ├───────┼────────────────┼───────────────┼────────────────┼───────────────┤
# │ min   │      4.3       │       2       │       1        │      0.1      │
# ├───────┼────────────────┼───────────────┼────────────────┼───────────────┤
# │ 25%   │      5.1       │      2.8      │      1.6       │      0.3      │
# ...

# %%
# Affichage d'un tableau bien formaté à l'aide de tabulate
print(tabulate(summary, headers='keys', tablefmt='pipe', numalign="right"))
# Out:
# |       |   sepal_length |   sepal_width |   petal_length |   petal_width |
# |:------|---------------:|--------------:|---------------:|--------------:|
# | count |            150 |           150 |            150 |           150 |
# | mean  |        5.84333 |       3.05733 |          3.758 |       1.19933 |
# | std   |       0.828066 |      0.435866 |         1.7653 |      0.762238 |
# | min   |            4.3 |             2 |              1 |           0.1 |
# | 25%   |            5.1 |           2.8 |            1.6 |           0.3 |
# | 50%   |            5.8 |             3 |           4.35 |           1.3 |
# | 75%   |            6.4 |           3.3 |            5.1 |           1.8 |
# | max   |            7.9 |           4.4 |            6.9 |           2.5 |

# %% [markdown]
# Dispersion via des boxplots

# %%
# Création des boxplots univariés pour chaque variable numérique
fig, axes = plt.subplots(1, 4, figsize=(16, 6))

for i, column in enumerate(iris.columns[:-1]):
    sns.boxplot(y=column, data=iris, ax=axes[i])
    axes[i].set_title(f"Boxplot de {column}")

plt.tight_layout()
plt.show()

# %%
# Visualisation des tendances centrales et de la dispersion à l'aide de boxplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for i, column in enumerate(iris.columns[:-1]):
    sns.boxplot(x="species", y=column, data=iris, palette="Set2", ax=axes[i//2, i%2])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14872\3902915884.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=column, data=iris, palette="Set2", ax=axes[i//2, i%2])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14872\3902915884.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=column, data=iris, palette="Set2", ax=axes[i//2, i%2])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14872\3902915884.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
